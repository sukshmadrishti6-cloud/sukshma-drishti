# %% [markdown]
# # 03 — Classical Baselines
#
# **SIH26139: Hybrid Quantum Machine Learning Platform for Early Disease Detection**
#
# This notebook evaluates classical ML baseline models:
# - Logistic Regression (L2 regularized)
# - Support Vector Classifier (RBF kernel)
# - Random Forest
# - XGBoost

# %%
print("Notebook 03: Classical Baselines initialized")
