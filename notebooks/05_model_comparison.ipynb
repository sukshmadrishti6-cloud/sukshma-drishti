# %% [markdown]
# # 05 — Model Comparison & Honest Evaluation
#
# **SIH26139: Hybrid Quantum Machine Learning Platform for Early Disease Detection**
#
# This notebook compares classical vs quantum ML models across full evaluation metrics:
# - Accuracy, F1-score, Precision, Recall, Sensitivity, Specificity
# - ROC-AUC and PR-AUC curves
# - Brier Score & Log Loss calibration
# - Quantum computational cost vs classical execution trade-off

# %%
print("Notebook 05: Model Comparison initialized")
